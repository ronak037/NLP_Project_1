# %%
#Reading Book
file = open(r"C:\Users\asus\Desktop\book\book1\book1.txt",encoding="utf8")
# variable T
T1 = file.read()

#Reading Book
file = open(r"C:\Users\asus\Desktop\book\book2\book2.txt",encoding="utf8")
# variable T
T2 = file.read()

# %% [markdown]
# # punctutaions provided by python

# %%
import string
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
translator = str.maketrans("","",string.punctuation)
T1=T1.translate(translator)
T2=T2.translate(translator)

# %%
import re

# %%
# Removing acknowledgement
T1 = re.sub("The[\s\S]*CONTENTS","",T1)
# Removing the last part(Transciber's Notes)
T1 = re.sub(r"Transcriber’s[\s\S]*",r"",T1)

# %%
# Removing acknowledgement
T2 = re.sub("The[\s\S]*CONTENTS","",T2)
# Removing the last part(Transciber's Notes)
T2 = re.sub(r"Transcriber’s[\s\S]*",r"",T2)

# %%
# Removing Chapter Names
T1=re.sub("[A-Z]{2,}","",T1)
print(T1[:1000])
# Out:
#                                I
#
#
#                                                                 Page
#    rabia and its inhabitantsLife and doctrine
#                 of Mohammed                                        1
#
#      ”   he Khalifs from Abu Bekr to Hesham                 53
#
#
#
#
#
#
#    he Frank ConfederacyClovis the Founder of
#                 the Frank Monarchy                                89
#
#      ”   ecline of the Merovingian PrincesThe Mayors
#                 of the PalacePepin of LandenPepin of
#                 HeristalCharles MartelThe Battle of
#                 Tours                                            108
#
#
#
#
#                                I
#
#
#
#
#
#
#                               I
#
#
#
#
# The Arabian peninsula called by the natives  by the
# Persians and Turks  forms the southwesternmost part of
# Asia It is bounded on the north by Syria and the ri

# %%
# Removing Chapter Names
T2=re.sub("[A-Z]{2,}","",T2)
print(T1[:1000])
# Out:
#                                I
#
#
#                                                                 Page
#    rabia and its inhabitantsLife and doctrine
#                 of Mohammed                                        1
#
#      ”   he Khalifs from Abu Bekr to Hesham                 53
#
#
#
#
#
#
#    he Frank ConfederacyClovis the Founder of
#                 the Frank Monarchy                                89
#
#      ”   ecline of the Merovingian PrincesThe Mayors
#                 of the PalacePepin of LandenPepin of
#                 HeristalCharles MartelThe Battle of
#                 Tours                                            108
#
#
#
#
#                                I
#
#
#
#
#
#
#                               I
#
#
#
#
# The Arabian peninsula called by the natives  by the
# Persians and Turks  forms the southwesternmost part of
# Asia It is bounded on the north by Syria and the ri

# %%
T1 = T1.lower()
T2=T2.lower()

# %%
# Removing Chapter Numbers
T1=re.sub("[0-9]+","",T1)
print(T1[:1000])
# Out:
#                                i
#
#
#                                                                 page
#    rabia and its inhabitantslife and doctrine
#                 of mohammed
#
#      ”   he khalifs from abu bekr to hesham
#
#
#
#
#
#
#    he frank confederacyclovis the founder of
#                 the frank monarchy
#
#      ”   ecline of the merovingian princesthe mayors
#                 of the palacepepin of landenpepin of
#                 heristalcharles martelthe battle of
#                 tours
#
#
#
#
#                                i
#
#
#
#
#
#
#                               i
#
#
#
#
# the arabian peninsula called by the natives  by the
# persians and turks  forms the southwesternmost part of
# asia it is bounded on the north by syria and the river euph

# %%
#removing punctuations one more time
translator = str.maketrans("","",string.punctuation)
T1=T1.translate(translator)
T2=T2.translate(translator)

# %%
T2=re.sub("[0-9]+","",T2)
print(T2[:1000])
# Out:
#
#
#
#
#
#
#
#
#           ’s
#
#           ’s
#
#
#
#
#     m
#
#
# it is by his huge novels and principally by those of the
# rougonmacquart series that m zola is known to the public and to
# the critics nevertheless he has found time during the thirty years
# of his busy literary career to publish about as many small stories
# now comprised in four separate volumes it is natural that his novels
# should present so very much wider and more attractive a subject for
# analysis that so far as i can discover even in france no critic has
# hitherto taken the shorter productions separately and discussed m
# zola as a maker of contes yet there is a very distinct interest
# in seeing how such a thunderer or bellower on the trumpet can breathe
# through silver and as a matter of fact the short stories reveal a
# m zola considerably dissimilar to the author of “nana” and of “la
# terre”a much more optimistic romantic and gentl

# %% [markdown]
# # splitting words

# %%
T1=T1.split()
T2=T2.split()

# %%
# FREQURNCY DISTRIBUTION OF T1 WITHOUT Lemmatisations
import nltk
freq_dist = nltk.FreqDist(T1)
import operator
sorted_T1 = sorted(freq_dist.items(),reverse=True, key=operator.itemgetter(1))
sorted_T1[:20]
# Out:
# [('the', 5192),
#  ('of', 3355),
#  ('and', 1852),
#  ('to', 1460),
#  ('his', 940),
#  ('in', 853),
#  ('a', 832),
#  ('was', 501),
#  ('by', 493),
#  ('he', 478),
#  ('had', 442),
#  ('with', 391),
#  ('that', 356),
#  ('from', 291),
#  ('or', 275),
#  ('which', 254),
#  ('at', 254),
#  ('their', 239),
#  ('on', 227),
#  ('as', 225)]

# %%
# FREQURNCY DISTRIBUTION OF T2 WITHOUT Lemmatisations
freq_dist = nltk.FreqDist(T2)
import operator
sorted_T2 = sorted(freq_dist.items(),reverse=True, key=operator.itemgetter(1))
sorted_T2[:20]
# Out:
# [('the', 2144),
#  ('of', 1111),
#  ('and', 795),
#  ('a', 779),
#  ('to', 740),
#  ('in', 615),
#  ('was', 475),
#  ('he', 407),
#  ('that', 350),
#  ('had', 308),
#  ('his', 296),
#  ('it', 271),
#  ('with', 262),
#  ('by', 217),
#  ('her', 209),
#  ('on', 205),
#  ('she', 205),
#  ('is', 203),
#  ('as', 197),
#  ('for', 172)]

# %%
# distribution of words with frequency for T1
m=sorted_T1[:20]
x_axis=[]
y_axis=[]
for i in range(20):
    x_axis.append(m[i][0])
    y_axis.append(m[i][1])
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.scatter(x_axis,y_axis)
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of tokens for T1")
plt.show()

# %%
# distribution of words with frequency for T2
m=sorted_T2[:20]
x_axis=[]
y_axis=[]
for i in range(20):
    x_axis.append(m[i][0])
    y_axis.append(m[i][1])
import matplotlib.pyplot as plt
plt.figure(figsize=(20,10))
plt.scatter(x_axis,y_axis)
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of tokens for T2")
plt.show()

# %%
T1 = " ".join(T1)
T2 = ' '.join(T2)
wordcloudT1=T1
wordcloudT2=T2

# %%
#tokenisation
import nltk
from nltk.tokenize import word_tokenize
T1 = word_tokenize(T1)

print(T1[:100])
# Out:
# ['i', 'page', 'rabia', 'and', 'its', 'inhabitantslife', 'and', 'doctrine', 'of', 'mohammed', '”', 'he', 'khalifs', 'from', 'abu', 'bekr', 'to', 'hesham', 'he', 'frank', 'confederacyclovis', 'the', 'founder', 'of', 'the', 'frank', 'monarchy', '”', 'ecline', 'of', 'the', 'merovingian', 'princesthe', 'mayors', 'of', 'the', 'palacepepin', 'of', 'landenpepin', 'of', 'heristalcharles', 'martelthe', 'battle', 'of', 'tours', 'i', 'i', 'the', 'arabian', 'peninsula', 'called', 'by', 'the', 'natives', 'by', 'the', 'persians', 'and', 'turks', 'forms', 'the', 'southwesternmost', 'part', 'of', 'asia', 'it', 'is', 'bounded', 'on', 'the', 'north', 'by', 'syria', 'and', 'the', 'river', 'euphrates', 'on', 'the', 'east', 'by', 'the', 'persian', 'gulf', 'on', 'the', 'south', 'by', 'the', 'indian', 'ocean', 'on', 'the', 'west', 'by', 'the', 'red', 'sea', 'or', 'arabian']

# %%
T2 = word_tokenize (T2)
print(T2[:100])
# Out:
# ['’', 's', '’', 's', 'm', 'it', 'is', 'by', 'his', 'huge', 'novels', 'and', 'principally', 'by', 'those', 'of', 'the', 'rougonmacquart', 'series', 'that', 'm', 'zola', 'is', 'known', 'to', 'the', 'public', 'and', 'to', 'the', 'critics', 'nevertheless', 'he', 'has', 'found', 'time', 'during', 'the', 'thirty', 'years', 'of', 'his', 'busy', 'literary', 'career', 'to', 'publish', 'about', 'as', 'many', 'small', 'stories', 'now', 'comprised', 'in', 'four', 'separate', 'volumes', 'it', 'is', 'natural', 'that', 'his', 'novels', 'should', 'present', 'so', 'very', 'much', 'wider', 'and', 'more', 'attractive', 'a', 'subject', 'for', 'analysis', 'that', 'so', 'far', 'as', 'i', 'can', 'discover', 'even', 'in', 'france', 'no', 'critic', 'has', 'hitherto', 'taken', 'the', 'shorter', 'productions', 'separately', 'and', 'discussed', 'm', 'zola']

# %%
## Lemmation
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

# Lemmatisation
lemmatizer = WordNetLemmatizer()
# forming a set of stopwords from english language
stop_words = set(stopwords.words('english'))
# creating an empty list
lemmatized_T1=[]
# traversing all the words
for word in T1:
# if the word has a length greater than or equal to 2 and is not a stopword
    if len(word) >= 2 and word not in stop_words:
    # then we append the word into the list lemmatized_T after performing␣lemmatization
    # using the lemmatize() function
        lemmatized_T1.append(lemmatizer.lemmatize(word))
# printing the list of lemmatized words
print(lemmatized_T1[:100])
# Out:
# ['page', 'rabia', 'inhabitantslife', 'doctrine', 'mohammed', 'khalif', 'abu', 'bekr', 'hesham', 'frank', 'confederacyclovis', 'founder', 'frank', 'monarchy', 'ecline', 'merovingian', 'princesthe', 'mayor', 'palacepepin', 'landenpepin', 'heristalcharles', 'martelthe', 'battle', 'tour', 'arabian', 'peninsula', 'called', 'native', 'persian', 'turk', 'form', 'southwesternmost', 'part', 'asia', 'bounded', 'north', 'syria', 'river', 'euphrates', 'east', 'persian', 'gulf', 'south', 'indian', 'ocean', 'west', 'red', 'sea', 'arabian', 'gulf', 'including', 'northeastern', 'desert', 'occupies', 'area', 'ten', 'time', 'extent', 'great', 'britain', 'ireland', 'connecting', 'link', 'asia', 'africa', 'latter', 'continent', 'joined', 'isthmus', 'suez', 'present', 'natural', 'feature', 'faithful', 'copy', 'colossal', 'tropical', 'neighbour', 'modified', 'however', 'imprint', 'strongly', 'marked', 'individual', 'character', 'result', 'peculiar', 'isolated', 'position', 'attempted', 'derivation', 'name', 'country', 'common', 'progenitor', 'joctanites', 'ismaelitesthe', 'two', 'race', 'assumed']

# %%
lemmatized_T2=[]
# traversing all the words
for word in T2:
# if the word has a length greater than or equal to 2 and is not a stopword
    if len(word) >= 2 and word not in stop_words:
    # then we append the word into the list lemmatized_T after performing␣lemmatization
    # using the lemmatize() function
        lemmatized_T2.append(lemmatizer.lemmatize(word))
# printing the list of lemmatized words
print(lemmatized_T2[:100])
# Out:
# ['huge', 'novel', 'principally', 'rougonmacquart', 'series', 'zola', 'known', 'public', 'critic', 'nevertheless', 'found', 'time', 'thirty', 'year', 'busy', 'literary', 'career', 'publish', 'many', 'small', 'story', 'comprised', 'four', 'separate', 'volume', 'natural', 'novel', 'present', 'much', 'wider', 'attractive', 'subject', 'analysis', 'far', 'discover', 'even', 'france', 'critic', 'hitherto', 'taken', 'shorter', 'production', 'separately', 'discussed', 'zola', 'maker', 'contes', 'yet', 'distinct', 'interest', 'seeing', 'thunderer', 'bellower', 'trumpet', 'breathe', 'silver', 'matter', 'fact', 'short', 'story', 'reveal', 'zola', 'considerably', 'dissimilar', 'author', 'nana', 'la', 'terre', 'much', 'optimistic', 'romantic', 'gentle', 'writer', 'moreover', 'nowhere', 'assailed', 'decency', 'severely', 'thirty', 'forty', 'short', 'story', 'would', 'never', 'named', 'among', 'enemy', 'mr', 'grundy', 'gate', 'palais', 'mazarin', 'would', 'long', 'ago', 'opened', 'receive', 'indeed', 'lion', 'mane']

# %% [markdown]
# # wordcloud with stopwords

# %%
T1 = " ".join(lemmatized_T1)
T2 = ' '.join(lemmatized_T2)

from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height=800,
background_color='white',stopwords={},collocations=False,
min_font_size=10).generate(wordcloudT1)
plt.figure(figsize=(8,8),facecolor=None,)
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud for T1")
plt.show()


####################################
####################################
####################################


from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height=800,
background_color='white',stopwords={},collocations=False,
min_font_size=10).generate(wordcloudT2)
plt.figure(figsize=(8,8),facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud for T2")
plt.show()

# %% [markdown]
# # Wordcloud without Stopwords

# %%
from wordcloud import WordCloud,STOPWORDS
stopwords = set(STOPWORDS) 
wordcloud = WordCloud(width = 800, height=800,
background_color='white',stopwords=stopwords,
min_font_size=10).generate(wordcloudT1)
plt.figure(figsize=(8,8),facecolor=None,)
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud for T1")
plt.show()


####################################
####################################
####################################


from wordcloud import WordCloud
wordcloud = WordCloud(width = 800, height=800,
background_color='white',stopwords=stopwords,
min_font_size=10).generate(wordcloudT2)
plt.figure(figsize=(8,8),facecolor=None)
plt.imshow(wordcloud)
plt.axis("off")
plt.title("Word Cloud for T2")
plt.show()

# %% [markdown]
# # FREQUENCY DISTRIBUTION OF WORD COUNT

# %%
len_list={}
for i in range(len(lemmatized_T1)):
    if len(lemmatized_T1[i]) not in len_list:
        len_list[len(lemmatized_T1[i])] = 1
    else:
        len_list[len(lemmatized_T1[i])] += 1
keys = list(len_list.keys())
values = list(len_list.values())
plt.figure(figsize=(10,10))
plt.bar(keys,values)
plt.xlabel("Word Length")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of word length for T1")
plt.show()


###########################################
###########################################
###########################################


len_list={}
for i in range(len(lemmatized_T2)):
    if len(lemmatized_T2[i]) not in len_list:
        len_list[len(lemmatized_T2[i])] = 1
    else:
        len_list[len(lemmatized_T2[i])] += 1
keys = list(len_list.keys())
values = list(len_list.values())
plt.figure(figsize=(10,10))
plt.bar(keys,values)
plt.xlabel("Word Length")
plt.ylabel("Frequency")
plt.title("Frequency Distribution of word length fot T2")
plt.show()

# %% [markdown]
# # POS TAGGING

# %%
Tagged_T1 =nltk.pos_tag(lemmatized_T1)
Tagged_T2=nltk.pos_tag(lemmatized_T2)

# %%
fdistw1 = nltk.FreqDist([t for (w, t) in Tagged_T1])
fdistw2 = nltk.FreqDist([t for (w, t) in Tagged_T2])
print(Tagged_T1[:50])
print('**********************')
print(Tagged_T2[:50])
# Out:
# [('page', 'NN'), ('rabia', 'JJ'), ('inhabitantslife', 'JJ'), ('doctrine', 'NN'), ('mohammed', 'VBN'), ('khalif', 'JJ'), ('abu', 'NN'), ('bekr', 'NN'), ('hesham', 'NN'), ('frank', 'VBD'), ('confederacyclovis', 'JJ'), ('founder', 'NN'), ('frank', 'NN'), ('monarchy', 'NN'), ('ecline', 'NN'), ('merovingian', 'JJ'), ('princesthe', 'NN'), ('mayor', 'NN'), ('palacepepin', 'NN'), ('landenpepin', 'NN'), ('heristalcharles', 'VBZ'), ('martelthe', 'JJ'), ('battle', 'NN'), ('tour', 'NN'), ('arabian', 'JJ'), ('peninsula', 'NN'), ('called', 'VBN'), ('native', 'JJ'), ('persian', 'JJ'), ('turk', 'NN'), ('form', 'NN'), ('southwesternmost', 'VBD'), ('part', 'NN'), ('asia', 'NN'), ('bounded', 'VBD'), ('north', 'JJ'), ('syria', 'NNS'), ('river', 'NN'), ('euphrates', 'VBZ'), ('east', 'JJ'), ('persian', 'JJ'), ('gulf', 'NN'), ('south', 'JJ'), ('indian', 'JJ'), ('ocean', 'NN'), ('west', 'JJS'), ('red', 'JJ'), ('sea', 'NN'), ('arabian', 'JJ'), ('gulf', 'NN')]
# **********************
# [('huge', 'JJ'), ('novel', 'NN'), ('principally', 'RB'), ('rougonmacquart', 'JJ'), ('series', 'NN'), ('zola', 'NNP'), ('known', 'VBN'), ('public', 'JJ'), ('critic', 'NN'), ('nevertheless', 'RB'), ('found', 'VBD'), ('time', 'NN'), ('thirty', 'JJ'), ('year', 'NN'), ('busy', 'JJ'), ('literary', 'JJ'), ('career', 'NN'), ('publish', 'VBD'), ('many', 'JJ'), ('small', 'JJ'), ('story', 'NN'), ('comprised', 'VBD'), ('four', 'CD'), ('separate', 'JJ'), ('volume', 'NN'), ('natural', 'JJ'), ('novel', 'JJ'), ('present', 'JJ'), ('much', 'JJ'), ('wider', 'NN'), ('attractive', 'JJ'), ('subject', 'JJ'), ('analysis', 'NN'), ('far', 'RB'), ('discover', 'RB'), ('even', 'RB'), ('france', 'RBR'), ('critic', 'JJ'), ('hitherto', 'NN'), ('taken', 'VBN'), ('shorter', 'JJR'), ('production', 'NN'), ('separately', 'RB'), ('discussed', 'VBD'), ('zola', 'NN'), ('maker', 'NN'), ('contes', 'VBZ'), ('yet', 'RB'), ('distinct', 'JJ'), ('interest', 'NN')]

# %% [markdown]
# # Keys in the corpous

# %%
print("No. of tags", len(fdistw1.keys()))
fdistw1.keys()
# Out:
# No. of tags 27
# dict_keys(['NN', 'JJ', 'VBN', 'VBD', 'VBZ', 'NNS', 'JJS', 'VBG', 'VBP', 'RBR', 'RB', 'CD', 'RBS', 'MD', 'VB', 'JJR', 'IN', 'DT', 'WP$', 'CC', 'NNP', 'FW', 'RP', 'WDT', 'WP', 'PRP', 'WRB'])

# %%
keys = (list(fdistw1.keys()))
# creating a list of the frequency of the various tokens
values = list(fdistw1.values())
# plotting a bar plot diagram of the frequency distribution
plt.figure(figsize=(10,10))
plt.bar(keys,values)
plt.xlabel("Tags")
plt.xticks(rotation=45)
plt.ylabel("Frequency")
plt.title("Frequency Distribution of tags in T1")
plt.show()

#####################################
######################################
#####################################

keys = (list(fdistw2.keys()))
# creating a list of the frequency of the various tokens
values = list(fdistw2.values())
# plotting a bar plot diagram of the frequency distribution
plt.figure(figsize=(10,10))
plt.bar(keys,values)
plt.xlabel("Tags")
plt.xticks(rotation=45)
plt.ylabel("Frequency")
plt.title("Frequency Distribution of tags in T2")
plt.show()
